# %% [markdown]
# # Librerias

# %%
import pandas as pd
import os

# %%
'''
# Crear la carpeta "data_python"
os.mkdir("data_python")

# Crear las subcarpetas "estudiantes" y "administrativos" dentro de "data_python"
os.mkdir(os.path.join("data_python", "estudiantes"))
os.mkdir(os.path.join("data_python", "administrativos"))
'''
# Out:
# '\n# Crear la carpeta "data_python"\nos.mkdir("data_python")\n\n# Crear las subcarpetas "estudiantes" y "administrativos" dentro de "data_python"\nos.mkdir(os.path.join("data_python", "estudiantes"))\nos.mkdir(os.path.join("data_python", "administrativos"))\n'

# %% [markdown]
# # Leer los datos

# %%
# Leer el archivo .xlsx en un DataFrame
df_2014 = pd.read_excel('data_python/estudiantes/2014__recurso.xlsx')
df_2015 = pd.read_excel('data_python/estudiantes/2015__recurso.xlsx')
df_2016 = pd.read_excel('data_python/estudiantes/2016__recurso.xlsx')
df_2017 = pd.read_excel('data_python/estudiantes/2017__recurso.xlsx')
df_2018 = pd.read_excel('data_python/estudiantes/2018__recurso.xlsx')
df_2019 = pd.read_excel('data_python/estudiantes/2019__recurso.xlsx')
df_2020 = pd.read_excel('data_python/estudiantes/2020__recurso.xlsx')

# %% [markdown]
# # Dar formato

# %%
def eliminar_filas_iniciales(df, n):
    df = df.iloc[n:].reset_index(drop=True)  # Eliminar las primeras n filas y restablecer los índices
    df.columns = df.iloc[0]  # Establecer la nueva primera fila como encabezado
    df = df[1:].reset_index(drop=True)  # Eliminar la antigua primera fila y restablecer los índices nuevamente
    return df

# %%
df_m_2014 = eliminar_filas_iniciales(df_2014, 5)
df_m_2015 = eliminar_filas_iniciales(df_2015, 5)
df_m_2016 = eliminar_filas_iniciales(df_2016, 5)
df_m_2017 = eliminar_filas_iniciales(df_2017, 5)
df_m_2018 = eliminar_filas_iniciales(df_2018, 7)
df_m_2019 = eliminar_filas_iniciales(df_2019, 8)
df_m_2020 = eliminar_filas_iniciales(df_2020, 8)

# %%
df_m_2020.head(2)
# Out:
# 0 CÓDIGO DE LA INSTITUCIÓN IES_PADRE INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)  \
# 0                     1101      1101        UNIVERSIDAD NACIONAL DE COLOMBIA
# 1                     1101      1101        UNIVERSIDAD NACIONAL DE COLOMBIA
#
# 0 PRINCIPAL O SECCIONAL ID SECTOR IES\tSECTOR IES ID CARACTER CARACTER IES  \
# 0             Principal         1         OFICIAL           4  Universidad
# 1             Principal         1         OFICIAL           4  Universidad
#
# 0 CÓDIGO DEL DEPARTAMENTO (IES) DEPARTAMENTO DE DOMICILIO DE LA IES  ...  \
# 0                            11                         Bogotá D.C.  ...
# 1                            11                         Bogotá D.C.  ...
#
# 0      DESC CINE CODIGO DETALLADO CÓDIGO DEL DEPARTAMENTO (PROGRAMA)  \
# 0  Producción agrícola y ganadera                                 11
# 1  Producción agrícola y ganadera                                 11
#
# 0 DEPARTAMENTO DE OFERTA DEL PROGRAMA CÓDIGO DEL MUNICIPIO (PROGRAMA)  \
# 0                         Bogotá D.C.                           11001
# 1                         Bogotá D.C.                           11001
#
# 0 MUNICIPIO DE OFERTA DEL PROGRAMA ID SEXO    SEXO   AÑO SEMESTRE INSCRITOS
# 0                     Bogotá, D.C.       1  Hombre  2020        1        87
# 1                     Bogotá, D.C.       1  Hombre  2020        2        49
#
# [2 rows x 39 columns]

# %%
pd.set_option('display.max_columns', None)
df_m_2020.describe()
# Out:
# 0       CÓDIGO DE LA INSTITUCIÓN  IES_PADRE  \
# count                      52390      52390
# unique                       321        275
# top                         2102       2102
# freq                        9223       9223
#
# 0               INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES) PRINCIPAL O SECCIONAL  \
# count                                             52390                 52390
# unique                                              275                     2
# top     UNIVERSIDAD NACIONAL ABIERTA Y A DISTANCIA UNAD             Principal
# freq                                               9223                 49023
#
# 0       ID SECTOR IES\tSECTOR IES  ID CARACTER CARACTER IES  \
# count       52390           52390        52390        52390
# unique          2               2            4            4
# top             2         PRIVADA            4  Universidad
# freq        26682           26682        33714        33714
#
# 0      CÓDIGO DEL DEPARTAMENTO (IES) DEPARTAMENTO DE DOMICILIO DE LA IES  \
# count                          52390                               52390
# unique                            28                                  28
# top                               11                         Bogotá D.C.
# freq                           29371                               29371
#
# 0      CÓDIGO DEL MUNICIPIO (IES) MUNICIPIO DE DOMICILIO DE LA IES  \
# count                       52390                            52390
# unique                         72                               72
# top                         11001                     Bogotá, D.C.
# freq                        29371                            29371
#
# 0      CÓDIGO SNIES DEL PROGRAMA          PROGRAMA ACADÉMICO  \
# count                      52390                       52390
# unique                     10982                        5244
# top      SIN PROGRAMA ESPECIFICO  ADMINISTRACION DE EMPRESAS
# freq                         790                        1119
#
# 0      ID NIVEL ACADÉMICO NIVEL ACADÉMICO ID NIVEL DE FORMACIÓN  \
# count               52390           52390                 52390
# unique                  2               2                    10
# top                    01        PREGRADO                    06
# freq                35474           35474                 22514
#
# 0      NIVEL DE FORMACIÓN ID METODOLOGÍA METODOLOGÍA ID ÁREA  \
# count               52390          52390       52390   52390
# unique                 10              5           5      10
# top         Universitaria             01  Presencial       6
# freq                22514          34907       34907   15797
#
# 0                                ÁREA DE CONOCIMIENTO ID NÚCLEO  \
# count                                           52390     52390
# unique                                             10        57
# top     Economía, administración, contaduría y afines        69
# freq                                            15797     12088
#
# 0      NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)  ID CINE CAMPO AMPLIO  \
# count                                 52390                 52390
# unique                                   57                    12
# top                          Administración                     4
# freq                                  12088                 17259
#
# 0                     DESC CINE CAMPO AMPLIO  ID CINE CAMPO ESPECIFICO  \
# count                                  52390                     52390
# unique                                    12                        40
# top     Administración de Empresas y Derecho                        41
# freq                                   17259                     14150
#
# 0                 DESC CINE CAMPO ESPECIFICO  ID CINE CODIGO DETALLADO  \
# count                                  52390                     52390
# unique                                    40                       107
# top     Educación comercial y administración                       413
# freq                                   14150                      8650
#
# 0      DESC CINE CODIGO DETALLADO CÓDIGO DEL DEPARTAMENTO (PROGRAMA)  \
# count                       52390                              52390
# unique                        105                                 34
# top      Gestión y administración                                 11
# freq                         8650                              11609
#
# 0      DEPARTAMENTO DE OFERTA DEL PROGRAMA CÓDIGO DEL MUNICIPIO (PROGRAMA)  \
# count                                52390                           52390
# unique                                  34                             372
# top                            Bogotá D.C.                           11001
# freq                                 11609                           11609
#
# 0      MUNICIPIO DE OFERTA DEL PROGRAMA  ID SEXO    SEXO    AÑO  SEMESTRE  \
# count                             52390    52390   52390  52390     52390
# unique                              364        2       2      1         2
# top                        Bogotá, D.C.        1  Hombre   2020         1
# freq                              11609    26628   26628  52390     26536
#
# 0       INSCRITOS
# count       52390
# unique        825
# top             1
# freq         6669

# %%
df_m_2014.describe()
# Out:
# 0       Código de \nla Institución  IES PADRE  \
# count                        38475      38475
# unique                         318        272
# top                           2102       2102
# freq                          4471       4471
#
# 0               Institución de Educación Superior (IES)  \
# count                                             38475
# unique                                              272
# top     UNIVERSIDAD NACIONAL ABIERTA Y A DISTANCIA UNAD
# freq                                               4471
#
# 0      Principal\n o\nSeccional  Id_Sector Sector IES  Id_Caracter  \
# count                     38475      38475      38475        38475
# unique                        2          2          2            4
# top                   PRINCIPAL          2    PRIVADA            4
# freq                      35905      21659      21659        24518
#
# 0      Caracter IES  Código del \ndepartamento\n(IES)  \
# count         38475                             38475
# unique            4                                28
# top     UNIVERSIDAD                                11
# freq          24518                             20053
#
# 0      Departamento de \ndomicilio de la IES  Código del \nMunicipio\n(IES)  \
# count                                  38475                          38475
# unique                                    28                             73
# top                              BOGOTA D.C.                          11001
# freq                                   20053                          20053
#
# 0      Municipio de\ndomicilio de la IES  Código \nSNIES del\nprograma  \
# count                              38475                         38475
# unique                                73                          8436
# top                          BOGOTA D.C.                          3274
# freq                               20053                           231
#
# 0               Programa Académico  Id_Nivel Nivel Académico  \
# count                        38475     38475           38475
# unique                        3606         2               2
# top     ADMINISTRACION DE EMPRESAS         1        PREGRADO
# freq                          1277     27758           27758
#
# 0       Id_Nivel_Formacion Nivel de Formación  Id_Metodologia Metodología  \
# count                38475              38475           38475       38475
# unique                   6                  6               3           3
# top                      6      UNIVERSITARIA               1  PRESENCIAL
# freq                 16780              16780           28214       28214
#
# 0       Id_Area                         Área de Conocimiento  Id_Nucleo  \
# count     38475                                        38475      38475
# unique        8                                            8         62
# top           6  ECONOMIA ADMINISTRACION CONTADURIA Y AFINES         69
# freq      12330                                        12330       8755
#
# 0      Núcleo Básico del Conocimiento (NBC)  \
# count                                 38475
# unique                                   56
# top                          ADMINISTRACION
# freq                                   8755
#
# 0       Código del \nDepartamento\n(Programa)  \
# count                                   38475
# unique                                     33
# top                                        11
# freq                                     9361
#
# 0      Departamento de oferta del programa  \
# count                                38475
# unique                                  33
# top                            BOGOTA D.C.
# freq                                  9361
#
# 0       Código del \nMunicipio\n(Programa) Municipio de oferta del programa  \
# count                                38475                            38475
# unique                                 291                              284
# top                                  11001                      BOGOTA D.C.
# freq                                  9361                             9361
#
# 0       Id Género     Género    Año  Semestre  Inscritos 2014
# count       38475      38475  38475     38475           38475
# unique          2          2      1         2             752
# top             1  MASCULINO   2014         1               1
# freq        19547      19547  38475     19605            4317

# %%
df_m_2019.columns
# Out:
# Index(['CÓDIGO DE LA INSTITUCIÓN', 'IES_PADRE',
#        'INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES)', 'PRINCIPAL O SECCIONAL',
#        'ID SECTOR IES', 'SECTOR IES', 'ID CARACTER', 'CARACTER IES',
#        'CÓDIGO DEL DEPARTAMENTO (IES)', 'DEPARTAMENTO DE DOMICILIO DE LA IES',
#        'CÓDIGO DEL MUNICIPIO', 'MUNICIPIO DE DOMICILIO DE LA IES',
#        'CÓDIGO SNIES DEL PROGRAMA', 'PROGRAMA ACADÉMICO', 'ID NIVEL ACADÉMICO',
#        'NIVEL ACADÉMICO', 'ID NIVEL DE FORMACIÓN', 'NIVEL DE FORMACIÓN',
#        'ID METODOLOGÍA', 'METODOLOGÍA', 'ID ÁREA', 'ÁREA DE CONOCIMIENTO',
#        'ID NÚCLEO', 'NÚCLEO BÁSICO DEL CONOCIMIENTO (NBC)',
#        'ID CINE CAMPO AMPLIO', 'DESC CINE CAMPO AMPLIO',
#        'ID CINE CAMPO ESPECIFICO', 'DESC CINE CAMPO ESPECIFICO',
#        'ID CINE CODIGO DETALLADO', 'DESC CINE CODIGO DETALLADO',
#        'CÓDIGO DEL DEPARTAMENTO (PROGRAMA)',
#        'DEPARTAMENTO DE OFERTA DEL PROGRAMA',
#        'CÓDIGO DEL MUNICIPIO (PROGRAMA)', 'MUNICIPIO DE OFERTA DEL PROGRAMA',
#        'ID SEXO', 'SEXO', 'AÑO', 'SEMESTRE', 'INSCRITOS '],
#       dtype='object', name=0)

# %%
columnas_a_eliminar = [
    'ID CINE CAMPO AMPLIO', 'DESC CINE CAMPO AMPLIO',
    'ID CINE CAMPO ESPECIFICO', 'DESC CINE CAMPO ESPECIFICO',
    'ID CINE CODIGO DETALLADO', 'DESC CINE CODIGO DETALLADO'
]

# %%
df_m_2019 = df_m_2019.drop(columnas_a_eliminar, axis=1)
df_m_2020 = df_m_2020.drop(columnas_a_eliminar, axis=1)

# %% [markdown]
# # Unir los df

# %%
print(df_m_2014.shape)
print(df_m_2015.shape)
print(df_m_2016.shape)
print(df_m_2017.shape)
print(df_m_2018.shape)
print(df_m_2019.shape)
print(df_m_2020.shape)
# Out:
# (38475, 33)
# (40419, 33)
# (42764, 33)
# (45804, 33)
# (44756, 33)
# (50200, 33)
# (52390, 33)

# %%
df_m_2018 = df_m_2018.rename(columns=lambda x: x.replace("\n", " "))
nuevos_nombres = df_m_2018.columns

# %%
# Renombrar las columnas 
df_m_2014.columns = nuevos_nombres
df_m_2015.columns = nuevos_nombres
df_m_2016.columns = nuevos_nombres
df_m_2017.columns = nuevos_nombres
df_m_2018.columns = nuevos_nombres
df_m_2019.columns = nuevos_nombres
df_m_2020.columns = nuevos_nombres

# %%
df_concatenado = pd.concat([df_m_2014, df_m_2015, df_m_2016, df_m_2017, df_m_2018, df_m_2019, df_m_2020], axis=0)
df = df_concatenado.reset_index(drop=True)

# %%
print(df.shape)
# Out:
# (314808, 33)

# %% [markdown]
# # Dar formato a los datos

# %%
lista = df.columns
for valor in lista:
    # Convertir la columna 'comuna' en números
    def convertir_a_numero(valor):
        try:
            return int(valor)
        except ValueError:
            return valor

    df[valor] = [convertir_a_numero(valor) for valor in df[valor]]

# %%
for i in lista:
    df[i] = df[i].apply(lambda x: x.title() if isinstance(x, str) else x)

# %% [markdown]
# # Limpiar los datos

# %%
# Obtenenos los valores unicos y vemos comapramos si un valor tiene mas de un codigo
def obtener_diccionario(df, columna_a, columna_b):
    codigos_unicos = df[columna_a].unique()
    diccionario = {}

    # Iterar sobre los códigos únicos
    for codigo in codigos_unicos:
        # Obtener los valores únicos de los nombres para cada código
        nombres_unicos = df[df[columna_a] == codigo][columna_b].unique()

        # Verificar si hay más de 2 valores únicos de nombres
        if len(nombres_unicos) >= 2:
            # Asignar los nombres únicos como valor para cada código en el diccionario
            diccionario[codigo] = nombres_unicos.tolist()

    return diccionario

resultado1 = obtener_diccionario(df, 'IES PADRE', 'Institución de Educación Superior (IES)')
resultado2 = obtener_diccionario(df, 'Institución de Educación Superior (IES)', 'IES PADRE')
print(resultado1)
print(resultado2)
# Out:
# {1206: ['UNIVERSIDAD DE NARIÑO', 'UNIVERSIDAD DE NARI¿O'], 1726: ['UNIVERSIDAD CATOLICA DE ORIENTE', 'UNIVERSIDAD CATOLICA DE ORIENTE -UCO'], 1804: ['UNIVERSIDAD AUTONOMA DEL CARIBE', 'UNIVERSIDAD AUTONOMA DEL CARIBE- UNIAUTONOMA'], 1826: ['UNIVERSIDAD ANTONIO NARIÑO', 'UNIVERSIDAD ANTONIO NARI¿O'], 1835: ['UNIVERSIDAD DE CIENCIAS APLICADAS Y AMBIENTALES UDCA.', 'UNIVERSIDAD DE CIENCIAS APLICADAS Y AMBIENTALES - UDCA'], 2211: ['INSTITUCION UNIVERSITARIA BELLAS ARTES Y CIENCIAS DE BOLIVAR', 'INSTITUCION UNIVERSITARIA BELLAS ARTES Y CIENCIAS DE BOL'], 2707: ['FUNDACION UNIVERSITARIA JUAN N. CORPAS', 'FUNDACI¿N UNIVERSITARIA JUAN N. CORPAS'], 2719: ['FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM', 'UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM', 'UNIVERSIDAD CAT¿LICA LUIS AMIG¿'], 2731: ['FUNDACION UNIVERSITARIA CATOLICA LUMEN GENTIUM', 'FUNDACION UNIVERSITARIA CATOLICA LUMEN GENTIUM - UNICAT¿LICA - Cali'], 2738: ['FUNDACION UNIVESITARIA EMPRESARIAL DE LA CAMARA DE COMERCIO DE BOGOTA', 'FUNDACION UNIVERSITARIA EMPRESARIAL DE LA CAMARA DE COMERCIO DE BOGOTA', 'FUNDACION UNIVERSITARIA EMPRESARIAL DE LA CAMARA DE COME'], 2739: ['FUNDACION DE ESTUDIOS SUPERIORES UNIVERSITARIOS DE URABA ANTONIO ROLDAN BETANCUR', 'FUNDACION DE ESTUDIOS SUPERIORES UNIVERSITARIOS DE URABA'], 2741: ['F
UNDACION UNIVERSITARIA TECNOLOGICO COMFENALCO - CARTAGE'], 3706: ['FUNDACION CENTRO COLOMBIANO DE ESTUDIOS PROFESIONALES, -F.C.E.C.E.P.', 'FUNDACION CENTRO COLOMBIANO DE ESTUDIOS PROFESIONALES, -'], 3710: ['FUNDACION TECNOLOGICA ANTONIO DE AREVALO', 'FUNDACION UNIVERSITARIA ANTONIO DE AREVALO - UNITECNAR'], 3712: ['FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y CONSULTORIA ADMINISTRATIVA-F-CIDCA-', 'FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y CONSULTORIA'], 3713: ['FUNDACION UNIVERSITARIA PARA EL DESARROLLO HUMANO - UNINPAHU', 'FUND ...
# {'INSTITUTO NACIONAL DE FORMACION TECNICA PROFESIONAL DE S': [4102, 4106]}

# %% [markdown]
# Instituto Nacional De Formacion Tecnica Profesional De S' es el único que tiene dos códigos. Manualmente, lo pondremos como 'Instituto Nacional De Formacion Tecnica Profesional De San Juan Del Cesar' cuando el código sea 4102, y como 'Instituto Nacional De Formacion Tecnica Profesional De San Andres' cuando el código sea 4106
# * 4102: ['Instituto Nacional De Formacion Tecnica Profesional De San Juan Del Cesar', 'Instituto Nacional De Formacion Tecnica Profesional De S'],
# * 4106: ['Instituto Nacional De Formacion Tecnica Profesional De San Andres', 'Instituto Nacional De Formacion Tecnica Profesional De S'],

# %%
# Filtrar y asignar el valor 
df.loc[df['IES PADRE'] == 4102, 'Institución de Educación Superior (IES)'] = 'Instituto Nacional De Formacion Tecnica Profesional De San Juan Del Cesar'
df.loc[df['IES PADRE'] == 4106, 'Institución de Educación Superior (IES)'] = 'Instituto Nacional De Formacion Tecnica Profesional De San Andres'

# %%
# Esta funcion entrega un diccionario con los valores a ser reemplazado 
def obtener_diccionario(d_f, col_codigos, col_valores):
    codigos_unicos = d_f[col_codigos].unique()
    diccionario = {}
    
    for codigo in codigos_unicos:
        nombres_unicos = d_f[df[col_codigos] == codigo][col_valores].unique()
        
        if len(nombres_unicos) > 1:
            diccionario[codigo] = nombres_unicos.tolist()

    lista_valores = [valor[0] for valor in diccionario.values()]
    diccionario_actualizado = {lista_valores[i]: valor for i, valor in enumerate(diccionario.values())}
    diccionario_invertido = {}

    for clave, valores in diccionario_actualizado.items():
        for valor in valores:
            diccionario_invertido.setdefault(valor, []).append(clave)
    
    return diccionario_invertido

# %%
# Obtenemos los valores a remplazar
p2 = obtener_diccionario(df, 'Código de  la Institución', 'Institución de Educación Superior (IES)')
print(p2)
# Out:
# {'Universidad De Nariño': ['Universidad De Nariño'], 'Universidad De Nari¿O': ['Universidad De Nariño'], 'Universidad Catolica De Oriente': ['Universidad Catolica De Oriente'], 'Universidad Catolica De Oriente -Uco': ['Universidad Catolica De Oriente'], 'Universidad Autonoma Del Caribe': ['Universidad Autonoma Del Caribe'], 'Universidad Autonoma Del Caribe- Uniautonoma': ['Universidad Autonoma Del Caribe'], 'Universidad Antonio Nariño': ['Universidad Antonio Nariño'], 'Universidad Antonio
# %%
# Reemplazamos los valores
p2 = {k: v[0] for k, v in p2.items()}
df["Institución de Educación Superior (IES)"] = df["Institución de Educación Superior (IES)"].replace(p2)

# %% [markdown]
# # lab

# %% [markdown]
# ## caracter

# %%
resultado1 = obtener_diccionario(df, 'ID Caracter', 'Caracter IES')
resultado2 = obtener_diccionario(df, 'Caracter IES', 'ID Caracter')
print(resultado1)
print(resultado2)
# Out:
# {'Institucion Universitaria/Escuela Tecnologica': ['Institucion Universitaria/Escuela Tecnologica'], 'Institución Universitaria/Escuela Tecnológica': ['Institucion Universitaria/Escuela Tecnologica'], 'Institucion Tecnologica': ['Institucion Tecnologica'], 'Institución Tecnológica': ['Institucion Tecnologica'], 'Institucion Tecnica Profesional': ['Institucion Tecnica Profesional'], 'Institución Técnica Profesional': ['Institucion Tecnica Profesional']}
# {}

# %%
# Obtenemos los valores a remplazar
p2 = obtener_diccionario(df, 'ID Caracter', 'Caracter IES')
p2 = {k: v[0] for k, v in p2.items()}
df["Caracter IES"] = df["Caracter IES"].replace(p2)

# %% [markdown]
# ## Departamento de  domicilio de la IES

# %%
resultado1 = obtener_diccionario(df, 'Código del  departamento (IES)', 'Departamento de  domicilio de la IES')
resultado2 = obtener_diccionario(df, 'Departamento de  domicilio de la IES', 'Código del  departamento (IES)')
print(resultado1)
print(resultado2)
# Out:
# {'Bogota D.C.': ['Bogota D.C.'], 'Bogotá D.C': ['Bogota D.C.'], 'Bogota D.C': ['Bogota D.C.'], 'Bogotá D.C.': ['Bogota D.C.'], 'Valle Del Cauca': ['Valle Del Cauca'], 'Valle Del C': ['Valle Del Cauca'], 'Boyaca': ['Boyaca'], 'Boyacá': ['Boyaca'], 'Cordoba': ['Cordoba'], 'Córdoba': ['Cordoba'], 'Caqueta': ['Caqueta'], 'Caquetá': ['Caqueta'], 'Choco': ['Choco'], 'Chocó': ['Choco'], 'San Andres Y Providencia': ['San Andres Y Providencia'], 'San Andrés Y Providencia': ['San Andres Y Providencia'], 'Archipiélag': ['San Andres Y Providencia'], 'Archipiélago De San Andrés, Providencia Y Santa Catalina': ['San Andres Y Providencia'], 'Atlantico': ['Atlantico'], 'Atlántico': ['Atlantico'], 'Bolivar': ['Bolivar'], 'Bolívar': ['Bolivar'], 'Narino': ['Narino'], 'Nariño': ['Narino'], 'Quindio': ['Quindio'], 'Quindío': ['Quindio'], 'Norte De Santander': ['Norte De Santander'], 'Norte De Sa': ['Norte De Santander'], 'Cundinamarca': ['Cundinamarca'], 'Cundinamarc': ['Cundinamarca'], 'La Guajira': ['La Guajira'], 'Guajira': ['La Guajira']}
# {}

# %%
# Obtenemos los valores a remplazar
p2 = obtener_diccionario(df, 'Código del  departamento (IES)', 'Departamento de  domicilio de la IES')
p2 = {k: v[0] for k, v in p2.items()}
df["Departamento de  domicilio de la IES"] = df["Departamento de  domicilio de la IES"].replace(p2)

# %% [markdown]
# ## Municipio de domicilio de la IES

# %%
resultado1 = obtener_diccionario(df, 'Código del  Municipio (IES)', 'Municipio de domicilio de la IES')
resultado2 = obtener_diccionario(df, 'Municipio de domicilio de la IES', 'Código del  Municipio (IES)')
print(resultado1)
print('hola')
print(resultado2)
# Out:
# {'BOGOTA D.C.': ['BOGOTA D.C.'], 'Bogotá, D.C.': ['BOGOTA D.C.'], 'MEDELLIN': ['MEDELLIN'], 'Medellín': ['MEDELLIN'], 'MANIZALES': ['MANIZALES'], 'Manizales': ['MANIZALES'], 'PALMIRA': ['PALMIRA'], 'Palmira': ['PALMIRA'], 'TUNJA': ['TUNJA'], 'Tunja': ['TUNJA'], 'DUITAMA': ['DUITAMA'], 'Duitama': ['DUITAMA'], 'SOGAMOSO': ['SOGAMOSO'], 'Sogamoso': ['SOGAMOSO'], 'CHIQUINQUIRA': ['CHIQUINQUIRA'], 'Chiquinquirá': ['CHIQUINQUIRA'], 'POPAYAN': ['POPAYAN'], 'Popayán': ['POPAYAN'], 'PEREIRA': ['PEREIRA'], 'Pereira': ['PEREIRA'], 'MONTERIA': ['MONTERIA'], 'Montería': ['MONTERIA'], 'NEIVA': ['NEIVA'], 'Neiva': ['NEIVA'], 'FLORENCIA': ['FLORENCIA'], 'Florencia': ['FLORENCIA'], 'QUIBDO': ['QUIBDO'], 'Quibdó': ['QUIBDO'], 'VILLAVICENCIO': ['VILLAVICENCIO'], 'Villavicencio': ['VILLAVICENCIO'], 'VALLEDUPAR': ['VALLEDUPAR'], 'Valledupar': ['VALLEDUPAR'], 'BUENAVENTURA': ['BUENAVENTURA'], 'Buenaventura': ['BUENAVENTURA'], 'AGUACHICA': ['AGUACHICA'], 'Aguachica': ['AGUACHICA'], 'LETICIA': ['LETICIA'], 'Leticia': ['LETICIA'], 'SAN ANDRES': ['SAN ANDRES'], 'San Andrés': ['SAN ANDRES'], 'BARRANQUILLA': ['BARRANQUILLA'], 'Barranquilla': ['BARRANQUILLA'], 'CALI': ['CALI'], 'Cali': ['CALI'], 'BUCARAMANGA': ['BUCARAMANGA'], 'Bucaramanga': ['BUCARAMANGA'], 'CARTAGENA': ['CARTAGENA'], 'Cartagena de Indias': ['CARTAGENA'], 'PASTO': ['PASTO'], 'Pasto': ['PASTO'], 'IBAGUE': ['IBAGUE'], 'Ibagué': ['IBAGUE'], 'ARMENIA': ['ARMENIA'], 'Armenia': ['ARMENIA'], 'CUCUTA': ['CUCUTA'], 'San José de Cúcuta': ['CUCUTA'], 'OCAÑA': ['OCAÑA'], 'Ocaña': ['OCAÑA', 'OCA?A'], 'OCA?A': ['OCAÑA', 'OCA?A'], 'PAMPLONA': ['PAMPLONA'], 'Pamplona': ['PAMPLONA'], 'SANTA MARTA': ['SANTA MARTA'], 'Santa Marta': ['SANTA MARTA'], 'FUSAGASUGA': ['FUSAGASUGA'], 'Fusagasugá': ['FUSAGASU
# 2             UNIVERSIDAD NACIONAL DE COLOMBIA              PRINCIPAL
# 3             UNIVERSIDAD NACIONAL DE COLOMBIA              PRINCIPAL
# 4             UNIVERSIDAD NACIONAL DE COLOMBIA              PRINCIPAL
# ...                                        ...                    ...
# 314803        UNIVERSIDAD NACIONAL DE COLOMBIA              Seccional
# 314804        UNIVERSIDAD NACIONAL DE COLOMBIA              Seccional
# 314805        UNIVERSIDAD NACIONAL DE COLOMBIA              Seccional
# 314806        UNIVERSIDAD NACIONAL DE COLOMBIA              Seccional
# 314807        UNIVERSIDAD NACIONAL DE COLOMBIA              Seccional
#
# 0      ID Sector IES Sector IES ID Caracter Caracter IES  \
# 0                  1    OFICIAL           4  UNIVERSIDAD
# 1                  1    OFICIAL           4  UNIVERSIDAD
# 2                  1    OFICIAL           4  UNIVERSIDAD
# 3                  1    OFICIAL           4  UNIVERSIDAD
# 4                  1    OFICIAL           4  UNIVERSIDAD
# ...              ...        ...         ...          ...
# 314803             1    OFICIAL           4  Universidad
# 314804             1    OFICIAL           4  Universidad
# 314805             1    OFICIAL           4  Universidad
# 314806             1    OFICIAL           4  Universidad
# 314807             1    OFICIAL           4  Universidad
#
# 0      Código del  departamento (IES) Departamento de  domicilio de la IES  \
# 0                                  11                          BOGOTA D.C.
# 1                                  11                          BOGOTA D.C.
# 2                                  11                          BOGOTA D.C.
# 3                                  11                          BOGOTA D.C.
# 4                                  11                          BOGOTA D.C.
# ...                               ...                                  ...
# 314803                             20                                Cesar
# 314804                             20                                Cesar
# 314805                             20                                Cesar
# 314806                             20                                Cesar
# 314807                             20                                Cesar
#
# 0      Código del  Municipio (IES) Municipio de domicilio de la IES  \
# 0                            11001                      BOGOTA D.C.
# 1                            11001                      BOGOTA D.C.
# 2                            11001                      BOGOTA D.C.
# 3                            11001                      BOGOTA D.C.
# 4                            11001                      BOGOTA D.C.
# ...                            ...                              ...
# 314803                       20621                           La Paz
# 314804                       20621                           La Paz
# 314805                       20621                           La Paz
# 314806                       20621                           La Paz
# 314807                       20621                           La Paz
#
# 0      Código  SNIES del programa                  Programa Académico  \
# 0                              38     ESPECIALIDAD EN CIRUGIA GENERAL
# 1                              38     ESPECIALIDAD EN CIRUGIA GENERAL
# 2                              39  ESPECIALIDAD EN CIRUGIA PEDIATRICA
# 3                              39  ESPECIALIDAD EN CIRUGIA PEDIATRICA
# 4                              40    ESPECIALIDAD EN CIRUGIA PLASTICA
# ...                           ...                                 ...
# 314803                     108086              INGENIERÍA MECATRÓNICA
# 314804    SIN PROGRAMA ESPECIFICO             SIN PROGRAMA ESPECIFICO
# 314805    SIN PROGRAMA ESPECIFICO             SIN PROGRAMA ESPECIFICO
# 314806    SIN PROGRAMA ESPECIFICO             SIN PROGRAMA ESPECIFICO
# 314807    SIN PROGRAMA ESPECIFICO             SIN PROGRAMA ESPECIFICO
#
# 0      ID Nivel Académico Nivel Académico    ID Nivel de Formación  \
# 0                       2        POSGRADO                        1
# 1                       2        POSGRADO                        1
# 2                       2        POSGRADO                        1
# 3                       2        POSGRADO                        1
# 4                       2        POSGRADO                        1
# ...                   ...             ...                      ...
# 314803                 01        PREGRADO                       06
# 314804                 01        PREGRADO  SIN PROGRAMA ESPECIFICO
# 314805                 01        PREGRADO  SIN PROGRAMA ESPECIFICO
# 314806                 01        PREGRADO  SIN PROGRAMA ESPECIFICO
# 314807                 01        PREGRADO  SIN PROGRAMA ESPECIFICO
#
# 0            Nivel de Formación           ID Metodología  \
# 0               ESPECIALIZACION                        1
# 1               ESPECIALIZACION                        1
# 2               ESPECIALIZACION                        1
# 3               ESPECIALIZACION                        1
# 4               ESPECIALIZACION                        1
# ...                         ...                      ...
# 314803            Universitaria                       01
# 314804  SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314805  SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314806  SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314807  SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
#
# 0                   Metodología                  ID Área  \
# 0                    PRESENCIAL                        4
# 1                    PRESENCIAL                        4
# 2                    PRESENCIAL                        4
# 3                    PRESENCIAL                        4
# 4                    PRESENCIAL                        4
# ...                         ...                      ...
# 314803               Presencial                        8
# 314804  SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314805  SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314806  SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314807  SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
#
# 0                               Área de Conocimiento                Id_Nucleo  \
# 0                               CIENCIAS DE LA SALUD                      445
# 1                               CIENCIAS DE LA SALUD                      445
# 2                               CIENCIAS DE LA SALUD                      445
# 3                               CIENCIAS DE LA SALUD                      445
# 4                               CIENCIAS DE LA SALUD                      445
# ...                                              ...                      ...
# 314803  Ingeniería, arquitectura, urbanismo y afines                      831
# 314804                       SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314805                       SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314806                       SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
# 314807                       SIN PROGRAMA ESPECIFICO  SIN PROGRAMA ESPECIFICO
#
# 0      Núcleo Básico del Conocimiento (NBC)  \
# 0                                  MEDICINA
# 1                                  MEDICINA
# 2                                  MEDICINA
# 3                                  MEDICINA
# 4                                  MEDICINA
# ...                                     ...
# 314803         Ingeniería mecánica y afines
# 314804              SIN PROGRAMA ESPECIFICO
# 314805              SIN PROGRAMA ESPECIFICO
# 314806              SIN PROGRAMA ESPECIFICO
# 314807              SIN PROGRAMA ESPECIFICO
#
# 0      Código del  Departamento (Programa)  \
# 0                                       11
# 1                                       11
# 2                                       11
# 3                                       11
# 4                                       11
# ...                                    ...
# 314803                                  20
# 314804             SIN PROGRAMA ESPECIFICO
# 314805             SIN PROGRAMA ESPECIFICO
# 314806             SIN PROGRAMA ESPECIFICO
# 314807             SIN PROGRAMA ESPECIFICO
#
# 0      Departamento de oferta del programa Código del  Municipio (Programa)  \
# 0                              BOGOTA D.C.                            11001
# 1                              BOGOTA D.C.                            11001
# 2                              BOGOTA D.C.                            11001
# 3                              BOGOTA D.C.                            11001
# 4                              BOGOTA D.C.                            11001
# ...                                    ...                              ...
# 314803                               Cesar                            20621
# 314804            SIN PROGRAMA ESPECIFICOA          SIN PROGRAMA ESPECIFICO
# 314805            SIN PROGRAMA ESPECIFICOA          SIN PROGRAMA ESPECIFICO
# 314806            SIN PROGRAMA ESPECIFICOA          SIN PROGRAMA ESPECIFICO
# 314807            SIN PROGRAMA ESPECIFICOA          SIN PROGRAMA ESPECIFICO
#
# 0      Municipio de oferta del programa ID Sexo       Sexo   Año Semestre  \
# 0                           BOGOTA D.C.       2   FEMENINO  2014        1
# 1                           BOGOTA D.C.       1  MASCULINO  2014        1
# 2                           BOGOTA D.C.       2   FEMENINO  2014        1
# 3                           BOGOTA D.C.       1  MASCULINO  2014        1
# 4                           BOGOTA D.C.       2   FEMENINO  2014        1
# ...                                 ...     ...        ...   ...      ...
# 314803                           La Paz       2      Mujer  2020        2
# 314804          SIN PROGRAMA ESPECIFICO       1     Hombre  2020        1
# 314805          SIN PROGRAMA ESPECIFICO       1     Hombre  2020        2
# 314806          SIN PROGRAMA ESPECIFICO       2      Mujer  2020        1
# 314807          SIN PROGRAMA ESPECIFICO       2      Mujer  2020        2
#
# 0      Inscripciones 2018
# 0                      48
# 1                      81
# 2                      48
# 3                      17
# 4                      46
# ...                   ...
# 314803                  1
# 314804                176
# 314805                286
# 314806                144
# 314807                265
#
# [314808 rows x 33 columns]

# %%
10              Código del  Municipio (IES)              77         314808
11         Municipio de domicilio de la IES             116         314808

# %%
df.describe(include='all')
# Out:
# 0       Código de  la Institución      IES PADRE  \
# count               314808.000000  314808.000000
# unique                        NaN            NaN
# top                           NaN            NaN
# freq                          NaN            NaN
# mean                  3001.120013    2992.056835
# std                   2439.196934    2430.590999
# min                   1101.000000    1101.000000
# 25%                   1710.000000    1710.000000
# 50%                   2102.000000    2102.000000
# 75%                   2833.000000    2833.000000
# max                   9933.000000    9931.000000
#
# 0               Institución de Educación Superior (IES)  \
# count                                            314808
# unique                                              366
# top     Universidad Nacional Abierta Y A Distancia Unad
# freq                                              43682
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
# 0      Principal  o Seccional  ID Sector IES Sector IES    ID Caracter  \
# count                  314808  314808.000000     314808  314808.000000
# unique                      2            NaN          2            NaN
# top                 Principal            NaN    Privada            NaN
# freq                   293947            NaN     165091            NaN
# mean                      NaN       1.524418        NaN       3.452533
# std                       NaN       0.499404        NaN       0.827747
# min                       NaN       1.000000        NaN       1.000000
# 25%                       NaN       1.000000        NaN       3.000000
# 50%                       NaN       2.000000        NaN       4.000000
# 75%                       NaN       2.000000        NaN       4.000000
# max                       NaN       2.000000        NaN       4.000000
#
# 0      Caracter IES  Código del  departamento (IES)  \
# count        314808                   314808.000000
# unique            7                             NaN
# top     Universidad                             NaN
# freq         201879                             NaN
# mean            NaN                       20.881858
# std             NaN                       21.966241
# min             NaN                        5.000000
# 25%             NaN                       11.000000
# 50%             NaN                       11.000000
# 75%             NaN                       17.000000
# max             NaN                       91.000000
#
# 0      Departamento de  domicilio de la IES  Código del  Municipio (IES)  \
# count                                314808                314808.000000
# unique                                   47                          NaN
# top                             Bogotá D.C.                          NaN
# freq                                  56342                          NaN
# mean                                    NaN                 20910.148087
# std                                     NaN                 21991.065412
# min                                     NaN                  5001.000000
# 25%                                     NaN                 11001.000000
# 50%                                     NaN                 11001.000000
# 75%                                     NaN                 17001.000000
# max                                     NaN                 91001.000000
#
# 0      Municipio de domicilio de la IES  Código  SNIES del programa  \
# count                            314808                    314808.0
# unique                              116                     15032.0
# top                         Bogota D.C.                      3274.0
# freq                              88284                      1660.0
# mean                                NaN                         NaN
# std                                 NaN                         NaN
# min                                 NaN                         NaN
# 25%                                 NaN                         NaN
# 50%                                 NaN                         NaN
# 75%                                 NaN                         NaN
# max                                 NaN                         NaN
#
# 0               Programa Académico  ID Nivel Académico Nivel Académico  \
# count                       314808            314808.0          314808
# unique                        8980                 4.0               3
# top     Administracion De Empresas                 1.0        Pregrado
# freq                          7742            214926.0          214926
# mean                           NaN                 NaN             NaN
# std                            NaN                 NaN             NaN
# min                            NaN                 NaN             NaN
# 25%                            NaN                 NaN             NaN
# 50%                            NaN                 NaN             NaN
# 75%                            NaN                 NaN             NaN
# max                            NaN                 NaN             NaN
#
# 0       ID Nivel de Formación Nivel de Formación  ID Metodología Metodología  \
# count                314808.0             314808        314808.0      314808
# unique                   12.0                 17             7.0          11
# top                       6.0      Universitaria             1.0  Presencial
# freq                 133773.0             133773        225048.0      225048
# mean                      NaN                NaN             NaN         NaN
# std                       NaN                NaN             NaN         NaN
# min                       NaN                NaN             NaN         NaN
# 25%                       NaN                NaN             NaN         NaN
# 50%                       NaN                NaN             NaN         NaN
# 75%                       NaN                NaN             NaN         NaN
# max                       NaN                NaN             NaN         NaN
#
# 0        ID Área                           Área de Conocimiento  Id_Nucleo  \
# count   314808.0                                         314808   314808.0
# unique      12.0                                             16       66.0
# top          6.0  Economía, Administración, Contaduría Y Afines       69.0
# freq     96787.0                                          71903    70441.0
# mean         NaN                                            NaN        NaN
# std          NaN                                            NaN        NaN
# min          NaN                                            NaN        NaN
# 25%          NaN                                            NaN        NaN
# 50%          NaN                                            NaN        NaN
# 75%          NaN                                            NaN        NaN
# max          NaN                                            NaN        NaN
#
# 0      Núcleo Básico del Conocimiento (NBC)  \
# count                                311661
# unique                                  121
# top                          Administración
# freq                                  52948
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
# 0       Código del  Departamento (Programa)  \
# count                              314808.0
# unique                                 39.0
# top                                    11.0
# freq                                72936.0
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
# 0      Departamento de oferta del programa  Código del  Municipio (Programa)  \
# count                               314141                          314808.0
# unique                                  54                             740.0
# top                              Antioquia                           11001.0
# freq                                 44248                           72936.0
# mean                                   NaN                               NaN
# std                                    NaN                               NaN
# min                                    NaN                               NaN
# 25%                                    NaN                               NaN
# 50%                                    NaN                               NaN
# 75%                                    NaN                               NaN
# max                                    NaN                               NaN
#
# 0      Municipio de oferta del programa       ID Sexo    Sexo            Año  \
# count                            314808  314808.00000  314808  314808.000000
# unique                              877           NaN       4            NaN
# top                         Bogota D.C.           NaN  Hombre            NaN
# freq                              40407           NaN  119797            NaN
# mean                                NaN       1.49223     NaN    2017.201072
# std                                 NaN       0.49994     NaN       1.996682
# min                                 NaN       1.00000     NaN    2014.000000
# 25%                                 NaN       1.00000     NaN    2015.000000
# 50%                                 NaN       1.00000     NaN    2017.000000
# 75%                                 NaN       2.00000     NaN    2019.000000
# max                                 NaN       2.00000     NaN    2020.000000
#
# 0            Semestre  Inscripciones 2018
# count   314808.000000       314808.000000
# unique            NaN                 NaN
# top               NaN                 NaN
# freq              NaN                 NaN
# mean         1.489610           45.103860
# std          0.499893          208.689036
# min          1.000000            1.000000
# 25%          1.000000            4.000000
# 50%          1.000000           12.000000
# 75%          2.000000           35.000000
# max          2.000000        26786.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314808 entries, 0 to 314807
# Data columns (total 33 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Código de  la Institución                314808 non-null  int64
#  1   IES PADRE                                314808 non-null  int64
#  2   Institución de Educación Superior (IES)  314808 non-null  object
#  3   Principal  o Seccional                   314808 non-null  object
#  4   ID Sector IES                            314808 non-null  int64
#  5   Sector IES                               314808 non-null  object
#  6   ID Caracter                              314808 non-null  int64
#  7   Caracter IES                             314808 non-null  object
#  8   Código del  departamento (IES)           314808 non-null  int64
#  9   Departamento de  domicilio de la IES     314808 non-null  object
#  10  Código del  Municipio (IES)              314808 non-null  int64
#  11  Municipio de domicilio de la IES         314808 non-null  object
#  12  Código  SNIES del programa               314808 non-null  object
#  13  Programa Académico                       314808 non-null  object
#  14  ID Nivel Académico                       314808 non-null  object
#  15  Nivel Académico                          314808 non-null  object
#  16  ID Nivel de Formación                    314808 non-null  object
#  17  Nivel de Formación                       314808 non-null  object
#  18  ID Metodología                           314808 non-null  object
#  19  Metodología                              314808 non-null  object
#  20  ID Área                                  314808 non-null  object
#  21  Área de Conocimiento                     314808 non-null  object
#  22  Id_Nucleo                                314808 non-null  object
#  23  Núcleo Básico del Conocimiento (NBC)     311661 non-null  object
#  24  Código del  Departamento (Programa)      314808 non-null  object
#  25  Departamento de oferta del programa      314141 non-null  object
#  26  Código del  Municipio (Programa)         314808 non-null  object
#  27  Municipio de oferta del programa         314808 non-null  object
#  28  ID Sexo                                  314808 non-null  int64
#  29  Sexo                                     314808 non-null  object
#  30  Año                                      314808 non-null  int64
#  31  Semestre                                 314808 non-null  int64
#  32  Inscripciones 2018                       314808 non-null  int64
# dtypes: int64(10), object(23)
# memory usage: 79.3+ MB

# %%
# Obtener el número de valores únicos en cada columna
valores_unicos = df.nunique()

# Obtener el número total de valores en cada columna
total_valores = df.count()

# Combinar los resultados en un nuevo DataFrame
resumen_valores_unicos = pd.DataFrame({
    'Columna': valores_unicos.index,
    'Valores Únicos': valores_unicos.values,
    'Total Valores': total_valores.values
})

# Imprimir el resumen de valores únicos
print(resumen_valores_unicos)
# Out:
#                                     Columna  Valores Únicos  Total Valores
# 0                 Código de  la Institución             338         314808
# 1                                 IES PADRE             289         314808
# 2   Institución de Educación Superior (IES)             366         314808
# 3                    Principal  o Seccional               2         314808
# 4                             ID Sector IES               2         314808
# 5                                Sector IES               2         314808
# 6                               ID Caracter               4         314808
# 7                              Caracter IES               7         314808
# 8            Código del  departamento (IES)              29         314808
# 9      Departamento de  domicilio de la IES              47         314808
# 10              Código del  Municipio (IES)              77         314808
# 11         Municipio de domicilio de la IES             116         314808
# 12               Código  SNIES del programa           15032         314808
# 13                       Programa Académico            8980         314808
# 14                       ID Nivel Académico               4         314808
# 15                          Nivel Académico               3         314808
# 16                    ID Nivel de Formación              12         314808
# 17                       Nivel de Formación              17         314808
# 18                           ID Metodología               7         314808
# 19                              Metodología              11         314808
# 20                                  ID Área              12         314808
# 21                     Área de Conocimiento              16         314808
# 22                                Id_Nucleo              66         314808
# 23     Núcleo Básico del Conocimiento (NBC)             121         311661
# 24      Código del  Departamento (Programa)              39         314808
# 25      Departamento de oferta del programa              54         314141
# 26         Código del  Municipio (Programa)             740         314808
# 27         Municipio de oferta del programa             877         314808
# 28                                  ID Sexo               2         314808
# 29                                     Sexo               4         314808
# 30                                      Año               7         314808
# 31                                 Semestre               2         314808
# 32                       Inscripciones 2018            1791         314808

# %%
def obtener_diccionario(d_f, col_codigos, col_valores):
    codigos_unicos = d_f[col_codigos].unique()
    diccionario = {}
    
    for codigo in codigos_unicos:
        nombres_unicos = d_f[df[col_codigos] == codigo][col_valores].unique()
        
        if len(nombres_unicos) > 1:
            diccionario[codigo] = nombres_unicos.tolist()

    lista_valores = [valor[0] for valor in diccionario.values()]
    diccionario_actualizado = {lista_valores[i]: valor for i, valor in enumerate(diccionario.values())}
    diccionario_invertido = {}

    for clave, valores in diccionario_actualizado.items():
        for valor in valores:
            diccionario_invertido.setdefault(valor, []).append(clave)
    
    return diccionario_invertido

# %%
p2 = obtener_diccionario(df, 'Código de  la Institución', 'Institución de Educación Superior (IES)')

# %%
p2
# Out:
# {'Universidad De Nariño': ['Universidad De Nariño'],
#  'Universidad De Nari¿O': ['Universidad De Nariño'],
#  'Universidad Catolica De Oriente': ['Universidad Catolica De Oriente'],
#  'Universidad Catolica De Oriente -Uco': ['Universidad Catolica De Oriente'],
#  'Universidad Autonoma Del Caribe': ['Universidad Autonoma Del Caribe'],
#  'Universidad Autonoma Del Caribe- Uniautonoma': ['Universidad Autonoma Del Caribe'],
#  'Universidad Antonio Nariño': ['Universidad Antonio Nariño'],
#  'Universidad Antonio Nari¿O': ['Universidad Antonio Nariño'],
#  'Corporacion Universitaria Para El Desarrollo Empresarial Y Social- Cudes': ['Corporacion Universitaria Para El Desarrollo Empresarial Y Social- Cudes'],
#  'Corporacion Universitaria Para El Desarrollo Empresarial': ['Corporacion Universitaria Para El Desarrollo Empresarial Y Social- Cudes'],
#  'Fundacion Universitaria Luis G. Paez': ['Fundacion Universitaria Luis G. Paez'],
#  'Fundacion Universitaria Luis G. Paez - Uniluisgpaez': ['Fundacion Universitaria Luis G. Paez'],
#  'Elite- Escuela Latinoamericana De Ingenieros, Tecnologos Y Empresarios': ['Elite- Escuela Latinoamericana De Ingenieros, Tecnologos Y Empresarios'],
#  'Elite- Escuela Latinoamericana De Ingenieros, Tecnologos': ['Elite- Escuela Latinoamericana De Ingenieros, Tecnologos Y Empresarios'],
#  'Eseit ¿ Escuela Superior De Empresa, Ingenier¿A Y Tecnolog¿A': ['Elite- Escuela Latinoamericana De Ingenieros, Tecnologos Y Empresarios'],
#  'Tecnologica Del Sur': ['Tecnologica Del Sur'],
#  'Corporaci¿N Tecnol¿Gica De Educaci¿N Superior Sapienza -Cte-': ['Tecnologica Del Sur'],
#  'Fundacion Universitaria Catolica Del Sur - Unicatolica Del Sur': ['Fundacion Universitaria Catolica Del Sur - Unicatolica Del Sur'],
#  'Fundacion Universitaria Catolica Del Sur - Unicatolica D': ['Fundacion Universitaria Catolica Del Sur - Unicatolica Del Sur'],
#  'Institucion Universitaria Digital De Antioquia -Iu. Digi': ['Institucion Universitaria Digital De Antioquia -Iu. Digi'],
#  'Institucion Universitaria Digital De Antioquia -Iu. Digital': ['Institucion Universitaria Digital De Antioquia -Iu. Digi'],
#  'Universidad Autónoma Indígena Intercultural - Uaiin': ['Universidad Autónoma Indígena Intercultural - Uaiin'],
#  'Universidad Aut¿Noma Ind¿Gena Intercultural - Uaiin': ['Universidad Autónoma Indígena Intercultural - Uaiin']}

# %%
p2 = {k: v[0] for k, v in p2.items()}
df["Institución de Educación Superior (IES)"] = df["Institución de Educación Superior (IES)"].replace(p2)

# %%
# df.to_csv('archivo.csv', index=False)

# %%
filtro = (df['Institución de Educación Superior (IES)'] == 'INSTITUTO NACIONAL DE FORMACION TECNICA PROFESIONAL DE SAN JUAN DEL CESAR') & (df['Código de  la Institución'] == 4106)
df_filtrado = df.loc[filtro]
df_filtrado
# Out:
# Empty DataFrame
# Columns: [Código de  la Institución, IES PADRE, Institución de Educación Superior (IES), Principal  o Seccional, ID Sector IES, Sector IES, ID Caracter, Caracter IES, Código del  departamento (IES), Departamento de  domicilio de la IES, Código del  Municipio (IES), Municipio de domicilio de la IES, Código  SNIES del programa, Programa Académico, ID Nivel Académico, Nivel Académico, ID Nivel de Formación, Nivel de Formación, ID Metodología, Metodología, ID Área, Área de Conocimiento, Id_Nucleo, Núcleo Básico del Conocimiento (NBC), Código del  Departamento (Programa), Departamento de oferta del programa, Código del  Municipio (Programa), Municipio de oferta del programa, ID Sexo, Sexo, Año, Semestre, Inscripciones 2018]
# Index: []

# %% [markdown]
# INSTITUTO NACIONAL DE FORMACION TECNICA PROFESIONAL DE S  (tiene 2 codigo 4106 y el 4102)  4106 =  INSTITUTO NACIONAL DE FORMACION TECNICA PROFESIONAL DE SAN ANDRES y 4102 = INSTITUTO NACIONAL DE FORMACION TECNICA PROFESIONAL DE SAN JUAN DEL CESAR

# %%
# Obtener el número de valores únicos en cada columna
valores_unicos = df.nunique()

# Obtener el número total de valores en cada columna
total_valores = df.count()

# Combinar los resultados en un nuevo DataFrame
resumen_valores_unicos = pd.DataFrame({
    'Columna': valores_unicos.index,
    'Valores Únicos': valores_unicos.values,
    'Total Valores': total_valores.values
})

# Imprimir el resumen de valores únicos
print(resumen_valores_unicos)
# Out:
#                                     Columna  Valores Únicos  Total Valores
# 0                 Código de  la Institución             338         314808
# 1                                 IES PADRE             289         314808
# 2   Institución de Educación Superior (IES)             289         314808
# 3                    Principal  o Seccional               2         314808
# 4                             ID Sector IES               2         314808
# 5                                Sector IES               2         314808
# 6                               ID Caracter               4         314808
# 7                              Caracter IES               4         314808
# 8            Código del  departamento (IES)              29         314808
# 9      Departamento de  domicilio de la IES              29         314808
# 10              Código del  Municipio (IES)              77         314808
# 11         Municipio de domicilio de la IES             116         314808
# 12               Código  SNIES del programa           15032         314808
# 13                       Programa Académico            8980         314808
# 14                       ID Nivel Académico               4         314808
# 15                          Nivel Académico               3         314808
# 16                    ID Nivel de Formación              12         314808
# 17                       Nivel de Formación              17         314808
# 18                           ID Metodología               7         314808
# 19                              Metodología              11         314808
# 20                                  ID Área              12         314808
# 21                     Área de Conocimiento              16         314808
# 22                                Id_Nucleo              66         314808
# 23     Núcleo Básico del Conocimiento (NBC)             121         311661
# 24      Código del  Departamento (Programa)              39         314808
# 25      Departamento de oferta del programa              54         314141
# 26         Código del  Municipio (Programa)             740         314808
# 27         Municipio de oferta del programa             877         314808
# 28                                  ID Sexo               2         314808
# 29                                     Sexo               4         314808
# 30                                      Año               7         314808
# 31                                 Semestre               2         314808
# 32                       Inscripciones 2018            1791         314808

# %%
# Obtener la cantidad de valores nulos por columna
valores_nulos = df.isnull().sum()

print(valores_nulos)
# Out:
# 0
# Código de  la Institución                     0
# IES PADRE                                     0
# Institución de Educación Superior (IES)       0
# Principal  o Seccional                        0
# ID Sector IES                                 0
# Sector IES                                    0
# ID Caracter                                   0
# Caracter IES                                  0
# Código del  departamento (IES)                0
# Departamento de  domicilio de la IES          0
# Código del  Municipio (IES)                   0
# Municipio de domicilio de la IES              0
# Código  SNIES del programa                    0
# Programa Académico                            0
# ID Nivel Académico                            0
# Nivel Académico                               0
# ID Nivel de Formación                         0
# Nivel de Formación                            0
# ID Metodología                                0
# Metodología                                   0
# ID Área                                       0
# Área de Conocimiento                          0
# Id_Nucleo                                     0
# Núcleo Básico del Conocimiento (NBC)       3147
# Código del  Departamento (Programa)           0
# Departamento de oferta del programa         667
# Código del  Municipio (Programa)              0
# Municipio de oferta del programa              0
# ID Sexo                                       0
# Sexo                                          0
# Año                                           0
# Semestre                                      0
# Inscripciones 2018                            0
# dtype: int64

# %%
fila_con_nulos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 fila_con_nulos
#
# NameError: name 'fila_con_nulos' is not defined
